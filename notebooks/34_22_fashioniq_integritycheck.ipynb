# %%
# !git clone https://github.com/okok0814/khoaluantotnghiep.git
# %cd khoaluantotnghiep
# Out:
# Cloning into 'khoaluantotnghiep'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 34 (delta 10), reused 22 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 285.12 KiB | 3.24 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# /content/khoaluantotnghiep

# %%
# !mkdir -p data/dataset3
# %cd data/dataset3

print("Đang tải FashionIQ Splits và Captions...")
# !git clone https://github.com/XiaoxiaoGuo/fashion-iq.git

print("Đang tải ASIN to URL mapping...")
# !git clone https://github.com/hongwang600/fashion-iq-metadata.git

# %cd /content/khoaluantotnghiep
print("\nCấu trúc thư mục data/dataset3 hiện tại:")
# !ls -la data/dataset3/
# Out:
# /content
# /content/khoaluantotnghiep
# /content/khoaluantotnghiep/data/dataset3
# Đang tải FashionIQ Splits và Captions...
# Cloning into 'fashion-iq'...
# remote: Enumerating objects: 140, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (21/21), done.
# Receiving objects: 100% (140/140), 1.48 MiB | 5.78 MiB/s, done.
# remote: Total 140 (delta 18), reused 10 (delta 10), pack-reused 109 (from 1)
# Resolving deltas: 100% (46/46), done.
# Đang tải ASIN to URL mapping...
# Cloning into 'fashion-iq-metadata'...
# remote: Enumerating objects: 17, done.
# remote: Total 17 (delta 0), reused 0 (delta 0), pack-reused 17 (from 1)
# Receiving objects: 100% (17/17), 1.49 MiB | 7.65 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/khoaluantotnghiep
#
# Cấu trúc thư mục data/dataset3 hiện tại:
# total 16
# drwxr-xr-x 4 root root 4096 Aug 25 14:53 .
# drwxr-xr-x 3 root root 4096 Aug 25 14:48 ..
# ...

# %%
# !python scripts/fashioniq_integrity_check.py
# Out:
# === 1. Split counts ===
#   dress    train : 11452
#   dress    val   : 3817
#   dress    test  : 3818
#   shirt    train : 19036
#   shirt    val   : 6346
#   shirt    test  : 6346
#   toptee   train : 16121
#   toptee   val   : 5373
#   toptee   test  : 5374
#   TOTAL: 77683
#
# === 2. Caption pair counts ===
#   dress    train : 5985
#   dress    val   : 2017
#   dress    test  : 2024
#   shirt    train : 5988
#   shirt    val   : 2038
#   shirt    test  : 2038
#   toptee   train : 6027
#   toptee   val   : 1961
#   toptee   test  : 2056
#   TOTAL: 30134
#
# === 3. ASIN->URL mapping coverage ===
#   dress   : 19087 referenced | 19087 have URL | 0 missing
#   shirt   : 31728 referenced | 31728 have URL | 0 missing
#   toptee  : 26868 referenced | 26868 have URL | 0 missing
#
# === 4. URL liveness sample check ===
#   # liveness = check_url_liveness(asin2url, sample_size=300)
#   # print(liveness)
# ...
