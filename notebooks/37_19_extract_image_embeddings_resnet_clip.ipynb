# %%
# !git clone https://github.com/okok0814/khoaluantotnghiep.git
# %cd khoaluantotnghiep
# Out:
# Cloning into 'khoaluantotnghiep'...
# remote: Enumerating objects: 136, done.
# remote: Counting objects: 100% (136/136), done.
# remote: Compressing objects: 100% (114/114), done.
# remote: Total 136 (delta 34), reused 115 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (136/136), 3.39 MiB | 13.31 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/khoaluantotnghiep

# %%
# !kaggle datasets download binhhuunguyen/fashioniq -p ./data
# !unzip -q -o ./data/fashioniq.zip -d ./data/fashioniq
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/binhhuunguyen/fashioniq
# License(s): unknown
# ...
# 100% 632M/632M [00:05<00:00, 119MB/s]

# %%
# !python scripts/extract_image_embeddings_resnet_clip.py --self_test
# Out:
# [triplets_test.csv] cột 'target': 1/1 dòng trống (bỏ qua khi gom ID, không tính vào embedding)
# [fake] Đã trích xuất 5/5 ảnh (1 ảnh thiếu file) trong 0.3s
# [fake] Đã lưu: /tmp/tmpwq9fyrjz/out/fake_image_embeddings.npz  shape=(5, 3)
# [SELF-TEST PASSED] Gom ID, xử lý ảnh thiếu, trích xuất theo batch, lưu/đọc .npz đều đúng.

# %%
# !python scripts/extract_image_embeddings_resnet_clip.py
# Out:
# [fashioniq_triplets_test.csv] cột 'target': 6118/6118 dòng trống (bỏ qua khi gom ID, không tính vào embedding)
# Tổng số image_id duy nhất cần trích xuất: 37725
# [resnet50] Đã trích xuất 37725/37725 ảnh (0 ảnh thiếu file) trong 155.1s
# [resnet50] Đã lưu: ./logs/thesis_embeddings/resnet50_image_embeddings.npz  shape=(37725, 2048)
# ...
# Loading weights: 100% 398/398 [00:00<00:00, 24083.29it/s]
# [clip] Đã trích xuất 37725/37725 ảnh (0 ảnh thiếu file) trong 135.3s
# [clip] Đã lưu: ./logs/thesis_embeddings/clip_image_embeddings.npz  shape=(37725, 512)
